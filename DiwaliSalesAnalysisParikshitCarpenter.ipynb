# %% [markdown]
# ## Parikshit Carpenter🥶

# %% [markdown]
# （づ￣3￣）づ╭❤️

# %% [markdown]
# #### Project Name: Diwali Sales Analysis

# %% [markdown]
# .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# %matplotlib notebook

# %%
data=pd.read_csv("D:\Analytics\Datasets\Diwali Rishabh Mishra\Diwali Sales Data.csv", encoding='latin1')
data.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df=data.copy()

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df['Amount']=df['Amount'].astype(int)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status':'Shaadi'}, inplace=True)

# %%
# describe() method describe the data we have, it tells us mean, median, standard deviation etc..etc...
df.describe()
# Out:
#             User_ID           Age        Shaadi        Orders        Amount
# count  1.123900e+04  11239.000000  11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357      0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866      0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000      0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000      1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28       0
# 1  1000732     Kartik  P00110942      F     26-35   35       1
# 2  1001990      Bindu  P00118542      F     26-35   35       1
# 3  1001425     Sudevi  P00237842      M      0-17   16       0
# 4  1000588       Joni  P00057942      M     26-35   28       1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Summarize the categorical data is by using the value_counts() function.
df.value_counts().to_frame()
# Out:
#                                                                                                                                      0
# User_ID Cust_name Product_ID Gender Age Group Age Shaadi State            Zone     Occupation   Product_Category      Orders Amount
# 1001883 Praneet   P00029842  M      51-55     54  1      Uttar Pradesh    Central  Hospitality  Auto                  1      23568   2
# 1000083 Gute      P00242842  M      26-35     35  0      Uttar Pradesh    Central  Hospitality  Clothing & Apparel    3      5345    2
# 1001325 Reese     P00111742  F      26-35     27  1      Gujarat          Western  Construction Electronics & Gadgets 3      7923    2
# 1001476 Anudeep   P00036842  M      18-25     25  0      Maharashtra      Western  IT Sector    Clothing & Apparel    4      5202    2
# 1001260 Dheeraj   P00344042  M      26-35     28  0      Maharashtra      Western  IT Sector    Electronics & Gadgets 4      8015    2
# ...

# %%
# plotting a bar chart for gender vs total amount 
sales_gen=df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
ax=sns.barplot(x='Gender', y='Amount', data=sales_gen)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men

# %% [markdown]
# ### Age

# %%
ax=sns.countplot(x='Age Group', hue='Gender', data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age=df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
ax=sns.barplot(x='Age Group', y='Amount', data=sales_age)

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female.

# %% [markdown]
# ### State

# %%
sales_state=df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
plt.figure(figsize=(15,5))
sns.barplot(data=sales_state, x='State', y='Orders')
plt.xticks(rotation=90)
plt.tight_layout()

# %%
# Total Amount/Sales from top 10 states
state_amt=df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# %%
sales_state['Total Amount']=state_amt['Amount']

# %%
sales_state=sales_state[:10]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='State', y='Total Amount', data=sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Total Amount'>

# %% [markdown]
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# ### Marital Status

# %%
df.rename(columns={'Shaadi':'Marital Status'}, inplace=True)

# %%
ax=sns.countplot(data=df, x='Marital Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_mar=df.groupby(['Marital Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
plt.figure(figsize=(15,5))
ax=sns.barplot(x='Marital Status', y='Amount',hue='Gender', data=sales_mar)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# ### Occupation

# %%
df['Occupation'].unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'Media', 'Banking', 'Retail',
#        'IT Sector', 'Aviation', 'Hospitality', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(x='Occupation', data=df)
plt.tight_layout()
plt.xticks(rotation=90)
plt.title('Sectors Worker Count')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_occup=df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
plt.figure(figsize=(15,8))
ax=sns.barplot(x='Occupation', y='Amount', data=sales_occup)
for bars in ax.containers:
    ax.bar_label(bars)
plt.tight_layout()

# %% [markdown]
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector.

# %% [markdown]
# ### Product Category

# %%
df['Product_Category'].unique()
# Out:
# array(['Auto', 'Hand & Power Tools', 'Stationery', 'Tupperware',
#        'Footwear & Shoes', 'Furniture', 'Food', 'Games & Toys',
#        'Sports Products', 'Books', 'Electronics & Gadgets', 'Decor',
#        'Clothing & Apparel', 'Beauty', 'Household items', 'Pet Care',
#        'Veterinary', 'Office'], dtype=object)

# %%
plt.figure(figsize=(10,8))
plt.tight_layout()
ax=sns.countplot(x='Product_Category', data=df)
plt.xticks(rotation=90)
plt.title('Sold Products Count')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_prod=df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
plt.figure(figsize=(15,8))
ax=sns.barplot(x="Product_Category", y="Amount", data=sales_prod.head(5))
plt.tight_layout()
# plt.xticks(rotation=90)

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# <img src="data:image/png;base64,..." width="1080">

# %% [markdown]
# From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category.

# %%
# %matplotlib notebook
# %matplotlib inline
# Out:
# <img src="data:image/png;base64,..." width="1080">
# <img src="data:image/png;base64,..." width="1440">
# <img src="data:image/png;base64,..." width="1080">

# %%
sales_prodID=df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
plt.figure(figsize=(20,6))
ax=sns.barplot(x='Product_ID', y='Orders', data=sales_prodID.head(20))
plt.tight_layout()

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Top 10 most sold products
fig1, ax1=plt.subplots(figsize=(15,5))
top_products=df.groupby(['Product_ID'])['Orders'].sum().nlargest(10).sort_values(ascending=False).reset_index()
ax=sns.barplot(x='Product_ID', y='Orders', ax=ax1, data=top_products)

# %% [markdown]
# The variable fig1 represents the figure object, which is the top-level container for all the plot elements. It allows you to modify the overall properties of the plot, such as the size, title, and saving the plot to a file.
#
# The variable ax1 represents the axes object. It is the actual plot area where you can plot your data and customize the individual axes properties, such as the labels, ticks, and grid.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Conclusion:
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category

# %% [markdown]
# .

# %% [markdown]
# ## Parikshit Carpenter🥶

# %% [markdown]
# .
